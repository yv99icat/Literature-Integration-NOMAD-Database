# %%
import pickle
with open("overlap_clusters.pkl", "rb") as f:
    overlap_clusters = pickle.load(f)

# %%
overlap_clusters
# Out:
# [                                              abstracts  cluster_labels
#  60    Perovskite absorbers have witnessed a remarkab...               0
#  161   Comparing to other carbon materials, the gener...               0
#  208   Iodine-doped graphite carbon nitride is utiliz...               0
#  214   A p-type and highly conductive reduced graphen...               0
#  216   Graphdiyne (GDY) is introduced into the FA0. 8...               0
#  ...                                                 ...             ...
#  3130  The hybrid perovskite/graphene oxide composite...               0
#  3236  Graphene oxide sheets (GOSs) are introduced be...               0
#  3280  A high open circuit voltage close to 1. 4 V is...               0
#  3302  Solution-processed oxo-functionalized graphene...               0
#  3356  Carbon‐based perovskite solar cells (PVSCs) wi...               0
#
#  [64 rows x 2 columns],
#                                                abstracts  cluster_labels
#  48    Fully solution-processed silver nanowire (AgNW...               1
#  178   Dramatic advances in perovskite solar cells (P...               1
#  210   Flexible perovskite solar cells based on polyd...               1
#  254   Wide applications of personal consumer electro...               1
#  260   Biomimetic crystallization has been developed ...               1
#  403   The Ag grid electrode is a candidate for use a...               1
#  472   Elastic perovskite solar cells, for the first ...               1
#  535   Flexible perovskite solar cells were fabricate...               1
#  554   In this study, the fabrication of highly effic...               1
#  571   Flexible, biocompatible, and light‐weight powe...               1
#  642   A promising energy source for many current and...               1
#  690   Owing to the sensitivity of the perovskite thi...               1
#  700   Silver nanowire (AgNW)‐based transparent elect...               1
#  818   Flexible perovskite solar cells with an ion pl...               1
#  839   All-inorganic large-area, low-cost, and durabl...               1
#  870   Flexible perovskite solar cells (PeSCs) hold g...               1
#  917   Flexible perovskite solar cells (f‐PSCs) have ...               1
#  1003  Embedding silver nanoparticles in the compact ...               1
#  1033  The performance of flexible perovskite solar c...               1
#  1249  Foldable paper‐based solar cells are attractiv...               1
#  1295  Highly efficient solar cells with sustainable ...               1
#  1530  A transparent conductive Ag nanowire (AgNW)-re...               1
#  1541  Flexible perovskite solar cells (PeSCs) posses...               1
#  1552  A flexible perovskite solar cell has been deve...               1
#  1680  By employing the neutral plane concept, we dem...               1
#  1801  Flexible perovskite solar cells have been deve...               1
#  1828  Ultralight and flexible perovskite solar cells...               1
#  1853  Perovskite solar cells have triggered a rapid ...               1
#  1877  Flexible perovskite solar cells (FPSCs) have v...               1
#  1885  Fully indium-free flexible Ag nanowires/ZnO:F ...               1
#  1894  Wearable devices are mainly based on plastic s...               1
#  1906  An efficient TeO2/Ag transparent top electrode...               1
#  1981  Solution‐processed metal nanowire networks hav...               1
#  2208  The rapid development of Internet of Things mo...               1
#  2221  Flexible electronics have attracted great inte...               1
#  2312  We report about a flexible substrate incorpora...               1
#  2429  Inspired by heliotropism in nature, a passive ...               1
#  2435  Flexible perovskite solar cells (PSCs) is bein...               1
#  2445  For the fabrication of deformable electronic d...               1
#  2536  Flexible perovskite solar cells are new techno...               1
#  2678  The electrical repair of device circuits has b...               1
#  3147  A TiO2/Ag(O)/ZnO configuration is developed fo...               1
#  3172  An efficient textile-based flexible perovskite...               1
#  3182  Ultrafine silver (Ag) nanowires dispersed in a...               1
#  3235  We investigated flexible W-doped In2O3 (IWO) e...               1
#  3303  Poly(ethylenimine) dramatically improved compa...               1
#  3349  We have studied characteristics of tin-doped i...               1,
#                                                abstracts  cluster_labels
#  30    The intrinsic characteristics of a ZnO electro...               2
#  34    ZnSe deposited using a normal thermal evaporat...               2
#  77    We adopted a wet-chemical method to deposit a ...               2
#  110   Low-temperature solution-processed ZnO/TiO2 bi...               2
#  150   Perovskite solar cells (PSCs) have advanced ra...               2
#  198   The preparation of ZnO structured films design...               2
#  395   Excimer laser annealing technique is successfu...               2
#  511   Solution-processed zinc oxide (ZnO)-based plan...               2
#  521   Fabrication of organohalide perovskite materia...               2
#  788   ZnO thin films having a nanocolumnar microstru...               2
#  945   In most current state‐of‐the‐art perovskite so...               2
#  1115  By combining the slow growth of the perovskite...               2
#  1131  Highly efficient and low-temperature processed...               2
#  1140  An electron‐transport layer (ETL) that selecti...               2
#  1257  ZnO is considered as a potential electron tran...               2
#  1468  ZnO/TiO2 NR array is a novelty candidate as an...               2
#  1571  Although ZnO is an attractive electron transpo...               2
#  1682  Significant efficiency improvements are report...               2
#  1708  A fast, simple and low temperature growth tech...               2
#  1776  To improve the performance of PSCs, interfacin...               2
#  1798  A compact and even ZnO:I nanopillar planar ele...               2
#  1813  Herein, this study reports high‐efficiency, lo...               2
#  2343  A sputtered ZnO thin film was used as electron...               2
#  2374  The aqueous processed ZnO/PCBM modified ETLs e...               2
#  2387  Perovskite solar cells have achieved the highe...               2
#  2701  ZnO thin films prepared by pulsed laser deposi...               2
#  2744  We examined the crystallization and crystal gr...               2
#  2755  Sputtering made ZnO thin film was used as an e...               2
#  2816  Defect states on the zinc oxide (ZnO) surface ...               2
#  2844  The power conversion efficiency of perovskite ...               2
#  2992  Perovskite photovoltaics (PVs) have attracted ...               2
#  3006  Despite dramatically improved efficiency of in...               2
#  3153  Low-temperature aqueous solution processed ZnO...               2
#  3184  ZnO nanorods (ZnO NRs) as electron transport l...               2,
#                                                abstracts  cluster_labels
#  11    Planar perovskite solar cells exhibit a conduc...               3
#  23    Nanotube (NT) layers of TiO2 are important one...               3
#  36    We report a simple methodology for the selecti...               3
#  55    Configuration of the perovskite solar cell and...               3
#  106   The ability to effectively transfer photoexcit...               3
#  ...                                                 ...             ...
#  3152  The light-weight perovskite solar cell is prep...               3
#  3253  TiO2nanoparticle/ITO nanowire nanocomposites f...               3
#  3335  High temperature processed anatase TiO2 utiliz...               3
#  3363  In this paper, we fabricated a TiO 2 homogeneo...               3
#  3365  A rutile TiO2 nanodendrite array (3D-RTNDA) co...               3
#
#  [117 rows x 2 columns],
#                                                abstracts  cluster_labels
#  16    Organic–inorganic hybrid perovskite solar cell...               5
#  281   A hybrid interfacial layer of ultrathin NiO/me...               5
#  316   Perovskite solar cells (PSCs) are one of the p...               5
#  332   High‐quality hole transport layers are prepare...               5
#  440   Here, a low-temperature solution-processed nic...               5
#  582   An industrially compatible in-line coating met...               5
#  620   Hybrid perovskites are on a trajectory toward ...               5
#  627   High-efficiency and long-term stable planar pe...               5
#  631   Herein, highly crystalline NiO nanosheets are ...               5
#  641   In perovskite solar cells (PSCs), the interfac...               5
#  701   A hysteresis-less inverted perovskite solar ce...               5
#  796   High‐quality charge carrier transport material...               5
#  829   Given that the highest certified conversion ef...               5
#  842   Herein, we demonstrate that lithium and cobalt...               5
#  876   Careful interface design and engineering are “...               5
#  882   Modified NiOx nanoparticles (NPs) developed vi...               5
#  906   Nickel oxide (NiOx)–based perovskite solar cel...               5
#  974   A new strategy is introduced to fabricate NiOx...               5
#  1049  Nickel oxide (NiO) is one of the most promisin...               5
#  1057  Nickel oxide (NiOx) is commonly used as a hole...               5
#  1061  A highly transparent NiO layer was prepared by...               5
#  1174  The synthesis and characterization of low‐temp...               5
#  1450  Nickel oxide (NiO) materials with excellent st...               5
#  1459  A high‐performing inverted perovskite solar ce...               5
#  1755  Perovskite has been adopted as photosensitizer...               5
#  1765  The effect of NiO x  (0 &lt; x) hole transport...               5
#  1790  Organometal halide perovskites have powerful i...               5
#  1799  Incorporating NiO NTs in perovskite films prov...               5
#  1842  A solution-derived NiOxfilm was successfully e...               5
#  1991  Post-thermal annealing and in situ doping are ...               5
#  2050  Nickel oxide (NiOx) is an attractive hole‐tran...               5
#  2201  An organic–inorganic integrated hole transport...               5
#  2255  The effect of annealing atmosphere and importa...               5
#  2368  Due to the rough surface of fluorine-doped tin...               5
#  2455  NiOx hole transporting layer has been extensiv...               5
#  2485  Inverted configuration perovskite solar cells ...               5
#  2581  The organometal halide perovskite (OHP) materi...               5
#  2585  This study proposes a novel strategy of contro...               5
#  2639  A large-scale (64 cm2), spray-coated nickel ox...               5
#  2753  Inverted perovskite solar cells incorporating ...               5
#  2822  A solution combustion synthesized hole transpo...               5
#  2878  Organometallic halide perovskite solar cells (...               5
#  2892  The effect of rapid oxidation temperature on t...               5
#  2902  NiO is a promising hole transporting material ...               5
#  2931  We demonstrated highly efficient and stable pe...               5
#  3077  Nickel oxide (NiOx) has exhibited great potent...               5
#  3096  Free standing Ni nanobelts dispersed in HTMs w...               5
#  3118  The effect of substitutional Li doping into Ni...               5
#  3309  We showed that perovskite solar cells employin...               5
#  3325  The organic-inorganic hybrid perovskites such ...               5,
#                                                abstracts  cluster_labels
#  4     High temperature stable inorganic CsPbX3 (X: I...               6
#  9     All-inorganic perovskites have a special place...               6
#  94    Inorganic halide perovskites such as cesium le...               6
#  134   Formamidinium-lead-iodide (FAPbI3)-based perov...               6
#  159   Csx(MA0. 17FA0. 83)1−xPb1−ySny(I0. 83Br0. 17)3...               6
#  ...                                                 ...             ...
#  3251  The fabrication of high‐quality perovskite fil...               6
#  3267  For solar cell applications, all-inorganic per...               6
#  3284  Cesium‐based inorganic perovskite solar cells ...               6
#  3316  Although organic–inorganic hybrid perovskite s...               6
#  3350  Oriented, large grain-sized CsPbI2Br perovskit...               6
#
#  [105 rows x 2 columns],
#                                                abstracts  cluster_labels
#  17    CuCrO2 with a crystal structure of delafossite...               8
#  95    Metal halide perovskites have emerged as one o...               8
#  157   Cu3PS4 nanoparticles are used as a new inorgan...               8
#  207   A solution-processable copper(ii) phthalocyani...               8
#  209   Solution‐processed hole transporting materials...               8
#  258   This study reports the development of copper(I...               8
#  362   The development of effective and stable hole t...               8
#  434   A delafossite CuCrO2hole transport layer depos...               8
#  605   Although perovskite solar cells (PSCs) surpass...               8
#  769   Solvothermal synthesized CuO nanoparticles are...               8
#  800   Cu/Cu2O films grown by ion beam sputtering wer...               8
#  828   Ligand modified Cu2ZnSnS4 (CZTS) nanoparticles...               8
#  860   Low-temperature solution-processed CuI/CuSCN c...               8
#  1002  An alternative hole transporting material Cu2−...               8
#  1235  Coper thiocyanate (CuSCN) is generally conside...               8
#  1493  p-Type wide-bandgap Cu2BaSnS4 holds promise fo...               8
#  1573  An effective strategy is developed to synthesi...               8
#  1672  Spiro‐OMeTAD is currently the most widely used...               8
#  1687  We have developed inorganic copper antimony su...               8
#  1795  Herein, solution‐processible inorganic hole‐tr...               8
#  1863  This study focuses on employing cuprous iodide...               8
#  1900  A simple and practical approach is introduced ...               8
#  1941  In high‐performance perovskite solar cells (PS...               8
#  1942  Low-cost inorganic copper iodide (CuI) is intr...               8
#  1969  State‐of‐the‐art Cu(In, Ga)Se2 (CIGS) solar ce...               8
#  1977  This paper reports on the fabrication of CuOx ...               8
#  1990  Copper phthalocyanine as an alternative hole s...               8
#  2037  Great efforts toward developing novel and effi...               8
#  2114  The utilization of an inorganic hole‐transport...               8
#  2146  Low cost copper phthalocyanine has been used a...               8
#  2267  CuSCN is a highly transparent, highly stable, ...               8
#  2366  Novel Cu/Cu2O composite films as a p-type tran...               8
#  2386  The viability of using solution-processed CuSC...               8
#  2615  Organic–inorganic halide perovskite solar cell...               8
#  2658  CuSCN, a low-cost inorganic HTM, exhibits high...               8
#  2737  The inorganic p‐type semiconductor CuI possess...               8
#  2911  Inorganic hole‐transport materials are commerc...               8
#  3030  Inorganic-organic metal halide perovskite sola...               8
#  3107  It is well known that the different proportion...               8
#  3131  Although perovskite solar cells can have power...               8
#  3203  We report the findings of a study into the sui...               8
#  3285  New efficient hole‐transport material (HTM) co...               8,
#                                                abstracts  cluster_labels
#  100   Three‐dimensional (3D) perovskite solar cells ...              13
#  121   Two-dimensional perovskites have emerged as mo...              13
#  171   Layered 2D organic–inorganic hybrid perovskite...              13
#  493   Quasi‐2D layered organometal halide perovskite...              13
#  537   Dion–Jacobson (DJ) type 2D perovskites with a ...              13
#  638   The fabrication of high‐quality film with larg...              13
#  645   Hybrid 3D/2D perovskites combine the high effi...              13
#  689   Highly efficient and stable 2D/3D hybrid perov...              13
#  750   2D halide perovskites have recently been recog...              13
#  831   2D Ruddlesden–Popper perovskite (RPP) solar ce...              13
#  873   Recently, two‐dimensional (2D) structure on th...              13
#  892   Formamidinium (FA)‐based 3D perovskite solar c...              13
#  1124  2D perovskites have attracted extensive attent...              13
#  1514  Thermal degradation in perovskite solar cells ...              13
#  1520  The replacement of a small amount of organic c...              13
#  1566  Recently, Ruddlesden–Popper perovskites (RPPs)...              13
#  1615  Phenethylammonium (PEA)‐based 2D perovskite is...              13
#  1627  A new series of 2D Ruddlesden–Popper halide pe...              13
#  1652  Perovskite solar cells (PSCs) have improved dr...              13
#  1679  Two‐dimensional perovskite solar cells (PSCs) ...              13
#  1719  Perovskite solar cells are one of the most pro...              13
#  1784  Increasing the power conversion efficiency (PC...              13
#  1923  2D perovskites with alternating cations in the...              13
#  2139  2D perovskites have emerged as one of the most...              13
#  2252  Dion–Jacobson (DJ) phase 2D layered perovskite...              13
#  2281  Layered two dimensional (layered 2D) organic–i...              13
#  2288  With the potential of achieving high efficienc...              13
#  2308  An important property of hybrid layered perovs...              13
#  2325  2D perovskites have recently been shown to exh...              13
#  2363  2D‐3D–structured formamidine perovskite compos...              13
#  2517  2D Ruddlesden–Popper (RP) perovskite solar cel...              13
#  2529  Organic spacer cations in layered 2D (A1)2(A2)...              13
#  2579  Hybrid halide 2D perovskites deserve special a...              13
#  2666  Ruddlesden–Popper perovskite (RPP) materials h...              13
#  2707  3D organic–inorganic lead halide perovskites h...              13
#  2728  Hybrid organic and inorganic perovskite solar ...              13
#  2752  Supported by the density functional theory (DF...              13
#  2959  Low‐dimensional Ruddlesden–Popper perovskites ...              13
#  2996  Tin‐based perovskites have exhibited high pote...              13
#  3058  Layered Ruddlesden–Popper (RP) phase (2D) hali...              13
#  3220  Quasi‐2D Ruddlesden–Popper (RP) perovskite sol...              13
#  3304  2D perovskites stabilized by alternating catio...              13
#  3343  The recent development of quasi‐2D perovskite ...              13,
#                                                abstracts  cluster_labels
#  22    Novel inverse‐vulcanized polymeric sulfur–sele...              14
#  63    A crosslinkable acrylate random copolymer with...              14
#  116   Perovskite solar cells are considered a promis...              14
#  117   New star-shaped hole transport materials inclu...              14
#  126   One of the obstacles to the commercialization ...              14
#  ...                                                 ...             ...
#  3260  Two low-cost methoxyaniline-substituted dibenz...              14
#  3299  Development of high‐performance dopant‐free ho...              14
#  3311  A dichlorobenzene‐functionalized hole‐transpor...              14
#  3313  A new type of hole transporting material (HTMs...              14
#  3340  Two new efficient hole transporting materials ...              14
#
#  [187 rows x 2 columns]]

# %%
# for contrastive loss function 

def generate_pairs(overlap_clusters):
    positive_pairs = []
    negative_pairs = []
    
    for cluster_df in overlap_clusters:
        abstracts = cluster_df["abstracts"].tolist()
        positive_pairs.extend([(a, b) for i, a in enumerate(abstracts) for b in abstracts[i+1:]])

    for i in range(len(overlap_clusters) - 1):
        cluster_1 = overlap_clusters[i]["abstracts"].tolist()
        for j in range(i + 1, len(overlap_clusters)):
            cluster_2 = overlap_clusters[j]["abstracts"].tolist()
            negative_pairs.extend([(a, b) for a in cluster_1 for b in cluster_2])

    return positive_pairs, negative_pairs

# %%
generate_pairs(overlap_clusters)
positive_pairs, negative_pairs = generate_pairs(overlap_clusters)

# %%
# Get the embedding for lower diemension
import pickle

with open("embedding_map.pkl", "rb") as f:
    embedding_map = pickle.load(f)


def get_embedding(text):
    return embedding_map.get(text, None)

# %%
import random

#  triplets loss function (Anchor, Positive, Negative)
def generate_triplets_from_list_of_dfs(cluster_dfs, num_triplets=5000):

    clusters = {i: df["abstracts"].tolist() for i, df in enumerate(cluster_dfs)}

    # Track how many times each abstract is used as an anchor
    anchors_used = {abstract: 0 for df in cluster_dfs for abstract in df["abstracts"].tolist()}

    triplets = []

    while len(triplets) < num_triplets:
        # Prioritize underused 
        anchor = min(anchors_used, key=anchors_used.get)
        anchor_cluster_idx = None


        for cluster_idx, abstracts in clusters.items():
            if anchor in abstracts:
                anchor_cluster_idx = cluster_idx
                break

        if anchor_cluster_idx is None:
            continue  

        # Select a positive sample from the same cluster (excluding anchor)
        anchor_cluster = clusters[anchor_cluster_idx]
        if len(anchor_cluster) > 1:
            positive = random.choice([p for p in anchor_cluster if p != anchor])
        else:
            continue  

        # Select a negative sample from a different cluster
        negative_cluster_idx = random.choice([i for i in clusters.keys() if i != anchor_cluster_idx])
        negative = random.choice(clusters[negative_cluster_idx])

        
        triplets.append((anchor, positive, negative))
        anchors_used[anchor] += 1  # Increase anchor selection count

    print(f"Generated {len(triplets)} triplets, ensuring balanced anchor selection.")
    return triplets

# %%
from sklearn.model_selection import train_test_split
train_clusters, holdout_clusters = [], []

for cluster_df in overlap_clusters:
    train_df, holdout_df = train_test_split(cluster_df, test_size=0.2, random_state=42)
    train_clusters.append(train_df)
    holdout_clusters.append(holdout_df)

# %%
holdout_clusters

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pickle
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import hdbscan
import pandas as pd
import random

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define a simple projection model to learnable transform embeddings
class ProjectionHead(nn.Module):
    def __init__(self, input_dim=768, output_dim=768):
        super(ProjectionHead, self).__init__()
        self.fc = nn.Linear(input_dim, output_dim)
        self.activation = nn.ReLU()
        self.fc2 = nn.Linear(output_dim, output_dim)
        self.layer_norm = nn.LayerNorm(output_dim)  # Use LayerNorm instead

    def forward(self, x):
        x = self.fc(x)
        x = self.activation(x)
        x = self.fc2(x)
        x = self.layer_norm(x)  
        return x


projection_model = ProjectionHead(input_dim=768, output_dim=768).to(device)
optimizer = optim.Adam(projection_model.parameters(), lr=1e-5)

# Define the dataset class for triplet loss
class TripletDataset(Dataset):
    def __init__(self, triplets, embedding_map, projection_model):
        self.triplets = triplets
        self.embedding_map = embedding_map
        self.projection_model = projection_model  # Pass projection model

    def __len__(self):
        return len(self.triplets)

    def __getitem__(self, idx):
        anchor_text, positive_text, negative_text = self.triplets[idx]

        # Convert embeddings to tensors & ensure requires_grad=True
        anchor = torch.tensor(self.embedding_map[anchor_text], dtype=torch.float32, requires_grad=True).to(device)
        positive = torch.tensor(self.embedding_map[positive_text], dtype=torch.float32, requires_grad=True).to(device)
        negative = torch.tensor(self.embedding_map[negative_text], dtype=torch.float32, requires_grad=True).to(device)

        # Pass through projection model to enable learning
        anchor = self.projection_model(anchor)
        positive = self.projection_model(positive)
        negative = self.projection_model(negative)

        return anchor, positive, negative

# Triplet loss function
class TripletLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(TripletLoss, self).__init__()
        self.margin = margin

    def forward(self, anchor, positive, negative):
        pos_dist = torch.nn.functional.pairwise_distance(anchor, positive)
        neg_dist = torch.nn.functional.pairwise_distance(anchor, negative)
        loss = torch.clamp(pos_dist - neg_dist + self.margin, min=0.0).mean()
        return loss


# Generate triplets
triplets = generate_triplets_from_list_of_dfs(train_df, num_triplets=5000)

dataset = TripletDataset(triplets, embedding_map, projection_model)
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)


# Initialize triplet loss function
criterion = TripletLoss(margin=1.0).to(device)

# Training loop
print("start training")
num_epochs = 10
for epoch in range(num_epochs):
    total_loss = 0.0
    for anchor, positive, negative in data_loader:
        optimizer.zero_grad()
        loss = criterion(anchor, positive, negative)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss:.4f}')

print('Training complete!')

# Save the trained model
torch.save(projection_model.state_dict(), 'projection_model.pth')
print('Model saved successfully!')

# %%
import numpy as np
new_embeddings = np.array([
    projection_model(torch.tensor(embedding_map[abstract], dtype=torch.float32).to(device)).detach().cpu().numpy()
    for abstract in embedding_map.keys()
])

new_embedding_map = {abstract: embedding for abstract, embedding in zip(embedding_map.keys(), new_embeddings)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import numpy as np
#       2 new_embeddings = np.array([
# ----> 3     projection_model(torch.tensor(embedding_map[abstract], dtype=torch.float32).to(device)).detach().cpu().numpy()
#       4     for abstract in embedding_map.keys()
#       5 ])
#       7 new_embedding_map = {abstract: embedding for abstract, embedding in zip(embedding_map.keys(), new_embeddings)}
#
# NameError: name 'projection_model' is not defined

# %%
new_embeddings_array = np.array(list(new_embedding_map.values()))

print("Shape of new embeddings:", new_embeddings_array.shape)

# %%
import pickle

embedding_path = 'embedding_map.pkl'

with open(embedding_path, 'rb') as f:
    embedding_map = pickle.load(f)

# %%
def generate_holdout_triplets(holdout_clusters, num_triplets=500):
    triplets = []
    for _ in range(num_triplets):
        # Choose one cluster
        cluster_pos = random.choice(holdout_clusters)
        if len(cluster_pos) < 2:
            continue
        anchor, positive = cluster_pos.sample(2)["abstracts"].values

        # Choose a different cluster for negative
        negative_cluster = random.choice([c for c in holdout_clusters if not c.equals(cluster_pos)])
        negative = negative_cluster.sample(1)["abstracts"].values[0]

        triplets.append((anchor, positive, negative))
    return triplets

# %%
def generate_holdout_triplets(holdout_clusters, num_triplets=500):
    triplets = []
    for _ in range(num_triplets):
        # Choose one cluster
        cluster_pos = random.choice(holdout_clusters)
        if len(cluster_pos) < 2:
            continue
        anchor, positive = cluster_pos.sample(2)["abstracts"].values

        # Choose a different cluster for negative
        negative_cluster = random.choice([c for c in holdout_clusters if not c.equals(cluster_pos)])
        negative = negative_cluster.sample(1)["abstracts"].values[0]

        triplets.append((anchor, positive, negative))
    return triplets

# %%
import torch
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Put your model in eval mode
projection_model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Step 1: Compute centroids from training clusters (overlap_clusters)
cluster_centroids = []
for cluster_df in train_clusters:
    vecs = []
    for abs_text in cluster_df["abstracts"]:
        if abs_text in embedding_map:
            emb = torch.tensor(embedding_map[abs_text], dtype=torch.float32).to(device)
            proj = projection_model(emb).detach().cpu().numpy()
            vecs.append(proj)
    if vecs:
        centroid = np.mean(vecs, axis=0)
        cluster_centroids.append(centroid)

# Step 2: Predict on holdout
# Step 2: Predict on holdout, with tracking of abstract names
true_labels = []
predicted_labels = []
abstract_names = []  # NEW: track abstract identifiers

for true_cluster_idx, cluster_df in enumerate(holdout_clusters):
    for abstract in cluster_df["abstracts"]:
        if abstract not in embedding_map:
            continue
        emb = torch.tensor(embedding_map[abstract], dtype=torch.float32).to(device)
        proj = projection_model(emb).detach().cpu().numpy()

        # Assign to nearest centroid
        distances = [np.linalg.norm(proj - c) for c in cluster_centroids]
        predicted_cluster = int(np.argmin(distances))

        true_labels.append(true_cluster_idx)
        predicted_labels.append(predicted_cluster)
        abstract_names.append(abstract)  # Save the abstract name


# Step 3: Accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f" Prediction Accuracy: {accuracy:.2%}")

# Step 4: Confusion Matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=range(len(cluster_centroids)),
            yticklabels=range(len(cluster_centroids)))
plt.xlabel("Predicted Cluster")
plt.ylabel("True Cluster")
plt.title(f"Confusion Matrix (Accuracy: {accuracy:.2%})")
plt.tight_layout()
plt.show()

# %%
closest_clusters = []        # Closest cluster indices
second_closest_clusters = [] # Second-closest cluster indices
second_closest_distances = [] # Distances to second closest

for true_cluster_idx, cluster_df in enumerate(holdout_clusters):
    for abstract in cluster_df["abstracts"]:
        if abstract not in embedding_map:
            continue
        emb = torch.tensor(embedding_map[abstract], dtype=torch.float32).to(device)
        proj = projection_model(emb).detach().cpu().numpy()

        distances = [np.linalg.norm(proj - c) for c in cluster_centroids]
        sorted_indices = np.argsort(distances)

        closest_idx = int(sorted_indices[0])
        second_idx = int(sorted_indices[1])

        true_labels.append(true_cluster_idx)
        predicted_labels.append(closest_idx)
        abstract_names.append(abstract)

        closest_clusters.append(closest_idx)
        second_closest_clusters.append(second_idx)
        second_closest_distances.append(distances[second_idx])

# %%
from collections import defaultdict

cluster_distance_stats = {}
distance_distributions = defaultdict(list)

for cluster_idx, cluster_df in enumerate(train_clusters):
    centroid = cluster_centroids[cluster_idx]
    for abstract in cluster_df["abstracts"]:
        if abstract in embedding_map:
            emb = torch.tensor(embedding_map[abstract], dtype=torch.float32).to(device)
            proj = projection_model(emb).detach().cpu().numpy()
            dist = np.linalg.norm(proj - centroid)
            distance_distributions[cluster_idx].append(dist)

# Compute mean and std per cluster
for idx, distances in distance_distributions.items():
    cluster_distance_stats[idx] = {
        'mean': np.mean(distances),
        'std': np.std(distances),
        'count': len(distances)
    }

# %%
for idx, dists in distance_distributions.items():
    plt.hist(dists, bins=20, alpha=0.6, label=f"Cluster {idx}")
plt.legend()
plt.xlabel("Distance to Cluster Centroid")
plt.ylabel("Frequency")
plt.title("Distance Distributions per Cluster")
plt.tight_layout()
plt.show()

# %%
# !pip install tf-keras

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict


# Settings
TOP_N = 15  # Top 10 bigrams per cluster

# ➡️ Custom words to exclude (you can extend this list)
custom_exclude_words = {'solar', 'perovskite', 'conversion',"perovskites","transport","cells pscs","perovskite films"}

# Prepare output
dataset_cluster_bigrams = []

# Process each dataset
for idx, df in enumerate(overlap_clusters):
    cluster_top_bigrams = defaultdict(list)

    for cluster_id in df['cluster_labels'].unique():
        abstracts_in_cluster = df[df['cluster_labels'] == cluster_id]['abstracts']

        # Initialize CountVectorizer for bigrams
        vectorizer = CountVectorizer(ngram_range=(2, 2), stop_words='english')
        X = vectorizer.fit_transform(abstracts_in_cluster)

        # Sum bigram counts
        bigram_counts = X.sum(axis=0).A1
        bigrams = vectorizer.get_feature_names_out()

        # Sort bigrams by frequency
        sorted_bigrams = sorted(zip(bigrams, bigram_counts), key=lambda x: x[1], reverse=True)

        # Select top non-repetitive, non-excluded bigrams
        selected_bigrams = []
        selected_words = set()
        for bigram, count in sorted_bigrams:
            words = bigram.split()
            # Check if any word is in the exclusion list
            if any(word in custom_exclude_words for word in words):
                continue
            if not (words[0] in selected_words or words[1] in selected_words):
                selected_bigrams.append(bigram)
                selected_words.update(words)
            if len(selected_bigrams) == TOP_N:
                break

        cluster_top_bigrams[cluster_id] = selected_bigrams

    dataset_cluster_bigrams.append(cluster_top_bigrams)

# Display results
for i, clusters in enumerate(dataset_cluster_bigrams):
    print(f"\nDataset {i}:")
    for cluster_id, bigrams in clusters.items():
        print(f"  Cluster {cluster_id}: {bigrams}")
# Out:
# Dataset 0:
#   Cluster 0: ['carbon based', 'cells pscs', 'graphene oxide', 'spiro ometad', 'efficient stable', 'photovoltaic performance', 'efficiency pce', 'formula text', 'low cost', 'hole extraction', 'charge recombination', 'long term', 'solution processed', 'counter electrode', 'htm free']
#
# Dataset 1:
#   Cluster 1: ['sheet resistance', 'efficiency pce', 'tin oxide', 'bending cycles', 'cells pscs', 'composite electrode', 'device performance', 'low cost', 'transparent conductive', 'wearable electronics', 'flexible pescs', 'metal substrate', 'power sources', 'radius mm', 'solution processed']
#
# Dataset 2:
#   Cluster 2: ['low temperature', 'cells pscs', 'zno based', 'solution processed', 'efficient stable', 'layer etl', 'charge recombination', 'efficiency pce', 'device stability', 'electron extraction', 'metal halide', 'surface modification', 'work function', 'active layers', 'aspect ratio']
#
# Dataset 3:
#   Cluster 3: ['cells pscs', 'tio2 layer', 'low temperature', 'efficiency pce', 'open circuit', 'tin oxide', 'fluorine doped', 'photovoltaic performance', 'spray pyrolysis', 'electron extraction', 'titanium dioxide', 'charge recombination', 'highly efficient', 'hole blocking', 'ticl4 treatment']
#
# Dataset 4:
#   Cluster 5: ['nickel oxide', 'efficiency pce', 'hole extraction', 'layer htl', 'cells pscs', 'inverted planar', 'niox film', 'open circuit', 'device performance', 'nio films', 'sol gel', 'large area', 'low temperature', 'organic inorganic', 'band alignment']
#
# Dataset 5:
#   Cluster 6: ['cells pscs', 'efficiency pce', 'high quality', 'circuit voltage', 'thermal stability', 'cesium lead', 'low temperature', 'organic inorganic', 'black phase', 'band gap', 'long term', 'device performance', 'ambient conditions', 'csxfa1 xpbi3', 'charge recombination']
#
# Dataset 6:
#   Cluster 8: ['hole transporting', 'cells pscs', 'spiro ometad', 'low cost', 'efficiency pce', 'cu cu2o', 'material htm', 'formula text', 'high performance', 'layer htl', 'pedot pss', 'solution processed', 'circuit current', 'f4 tcnq', 'long term']
#
# Dataset 7:
#   Cluster 13: ['quasi 2d', 'ruddlesden popper', 'efficiency pce', 'spacer cations', 'cells pscs', 'charge carrier', 'ma 3pb4i13', 'relative humidity', '3d hybrid', 'efficient stable', 'circuit voltage', 'high quality', 'binding energy', 'crystal growth', 'device performance']
#
# Dataset 8:
#   Cluster 14: ['hole transporting', 'spiro ometad', 'dopant free', 'materials htms', 'cells pscs', 'efficiency pce', 'material htm', 'tetrakis di', 'low cost', 'high performance', 'energy levels', 'small molecule', 'devices based', 'pedot pss', 'designed synthesized']

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/lib64/python3.13/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/lib64/python3.13/site-packages (from scikit-learn) (1.11.3)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 77.2 MB/s eta 0:00:00
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.0 scikit-learn-1.6.1 threadpoolctl-3.6.0

# %%
final_label_list = []

for dataset_bigrams in dataset_cluster_bigrams:
    for cluster_bigrams in dataset_bigrams.values():
        final_label_list.extend(cluster_bigrams)

# Optional: remove duplicates
final_label_list = list(set(final_label_list))

# %%
final_label_list
# Out:
# ['zno based',
#  'ticl4 treatment',
#  'nio films',
#  'niox film',
#  'device stability',
#  'sheet resistance',
#  'device performance',
#  'organic inorganic',
#  'carbon based',
#  'small molecule',
#  'titanium dioxide',
#  'cu cu2o',
#  'fluorine doped',
#  'tin oxide',
#  'photovoltaic performance',
#  '3d hybrid',
#  'csxfa1 xpbi3',
#  'low temperature',
#  'ambient conditions',
#  'black phase',
#  'pedot pss',
#  'material htm',
#  'f4 tcnq',
#  'layer etl',
#  'metal substrate',
#  'open circuit',
#  'bending cycles',
#  'highly efficient',
#  'aspect ratio',
#  'spacer cations',
#  'layer htl',
#  'designed synthesized',
#  'ma 3pb4i13',
#  'high performance',
#  'cesium lead',
#  'relative humidity',
#  'hole transporting',
#  'active layers',
#  'spiro ometad',
#  'metal halide',
#  'formula text',
#  'spray pyrolysis',
#  'quasi 2d',
#  'band alignment',
#  'solution processed',
#  'composite electrode',
#  'dopant free',
#  'nickel oxide',
#  'binding energy',
#  'efficient stable',
#  'power sources',
#  'materials htms',
#  'counter electrode',
#  'efficiency pce',
#  'low cost',
#  'tio2 layer',
#  'high quality',
#  'radius mm',
#  'inverted planar',
#  'wearable electronics',
#  'cells pscs',
#  'devices based',
#  'hole blocking',
#  'crystal growth',
#  'htm free',
#  'band gap',
#  'charge carrier',
#  'flexible pescs',
#  'circuit current',
#  'charge recombination',
#  'sol gel',
#  'large area',
#  'tetrakis di',
#  'work function',
#  'transparent conductive',
#  'energy levels',
#  'hole extraction',
#  'surface modification',
#  'graphene oxide',
#  'long term',
#  'ruddlesden popper',
#  'thermal stability',
#  'circuit voltage',
#  'electron extraction']

# %%
raw_abstracts= pd.read_csv('../api_fetcher/cleaned_abstracts.csv')
raw_abstracts = raw_abstracts["abstracts"]

# %%
raw_abstracts[0]
# Out:
# 'We modulated a solvent-mediated adduct for one-step crystallization of lead-free AgBi2I7 at a lower temperature (90 °C) and to obtain remnant BiI3 by controlling the nature of the substrate and precursor concentration. '

# %%
raw_abstracts[1]
# Out:
# 'The device performance is enhanced by doping a small percentage of polyethylenimine (PEI) into the PCBM. '

# %%
raw_abstracts[2]
# Out:
# 'Lead halide perovskites have emerged as successful optoelectronic materials with high photovoltaic power conversion efficiencies and low material cost. However, substantial challenges remain in the scalability, stability and fundamental understanding of the materials. Here we present the application of radiative thermal annealing, an easily scalable processing method for synthesizing formamidinium lead iodide (FAPbI3) perovskite solar absorbers. Devices fabricated from films formed via radiative thermal annealing have equivalent efficiencies to those annealed using a conventional hotplate. By coupling results from in situ X-ray diffraction using a radiative thermal annealing system with device performances, we mapped the processing phase space of FAPbI3 and corresponding device efficiencies. Our map of processing-structure-performance space suggests the commonly used FAPbI3 annealing time, 10 min at 170 °C, can be significantly reduced to 40 s at 170 °C without affecting the photovoltaic performance. The Johnson-Mehl-Avrami model was used to determine the activation energy for decomposition of FAPbI3 into PbI2. '

# %%
raw_abstracts[3]
# Out:
# 'Several applications of perovskite solar cells (PSCs) demand a semitransparent top electrode to afford top‐illumination or see‐through devices. Transparent conductive oxides, such as indium tin oxide (ITO), typically require postdeposition annealing at elevated temperatures, which would thermally decompose the perovskite. In contrast, silver nanowires (AgNWs) in dispersions of water would be a very attractive alternative that can be deposited at ambient conditions. Water is environmentally friendly without safety concerns associated with alcohols, such as flammability. Due to the notorious moisture sensitivity of lead‐halide perovskites, aqueous processing of functional layers, such as electrodes, on top of a perovskite device stack is elusive. Here, impermeable electron transport layers (ETLs) are shown to enable the deposition of semitransparent AgNW electrodes from green aqueous dispersions on top of the perovskite cell without damage. The polyvinylpyrrolidone (PVP) capping agent of the AgNWs is found to cause a work–function shift and an energy barrier between the AgNWs and the adjacent ETL. Thus, a high carrier density (≈1018 cm−3) in the ETL is required to achieve well‐behaved J/V characteristics free of s‐shapes. Ultimately, semitransparent PSCs are demonstrated that provide an efficiency of 17. 4%, which is the highest efficiency of semitransparent p‐i‐n perovskite solar cells with an AgNW top electrode. '

# %%
with open('final_label_list.pkl', 'wb') as f:
    pickle.dump(final_label_list, f)

# %%
final_label_list
# Out:
# ['zno based',
#  'ticl4 treatment',
#  'nio films',
#  'niox film',
#  'device stability',
#  'sheet resistance',
#  'device performance',
#  'organic inorganic',
#  'carbon based',
#  'small molecule',
#  'titanium dioxide',
#  'cu cu2o',
#  'fluorine doped',
#  'tin oxide',
#  'photovoltaic performance',
#  '3d hybrid',
#  'csxfa1 xpbi3',
#  'low temperature',
#  'ambient conditions',
#  'black phase',
#  'pedot pss',
#  'material htm',
#  'f4 tcnq',
#  'layer etl',
#  'metal substrate',
#  'open circuit',
#  'bending cycles',
#  'highly efficient',
#  'aspect ratio',
#  'spacer cations',
#  'layer htl',
#  'designed synthesized',
#  'ma 3pb4i13',
#  'high performance',
#  'cesium lead',
#  'relative humidity',
#  'hole transporting',
#  'active layers',
#  'spiro ometad',
#  'metal halide',
#  'formula text',
#  'spray pyrolysis',
#  'quasi 2d',
#  'band alignment',
#  'solution processed',
#  'composite electrode',
#  'dopant free',
#  'nickel oxide',
#  'binding energy',
#  'efficient stable',
#  'power sources',
#  'materials htms',
#  'counter electrode',
#  'efficiency pce',
#  'low cost',
#  'tio2 layer',
#  'high quality',
#  'radius mm',
#  'inverted planar',
#  'wearable electronics',
#  'cells pscs',
#  'devices based',
#  'hole blocking',
#  'crystal growth',
#  'htm free',
#  'band gap',
#  'charge carrier',
#  'flexible pescs',
#  'circuit current',
#  'charge recombination',
#  'sol gel',
#  'large area',
#  'tetrakis di',
#  'work function',
#  'transparent conductive',
#  'energy levels',
#  'hole extraction',
#  'surface modification',
#  'graphene oxide',
#  'long term',
#  'ruddlesden popper',
#  'thermal stability',
#  'circuit voltage',
#  'electron extraction']
